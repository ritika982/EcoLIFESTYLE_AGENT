# %% [markdown]
# The following notebook example will allow you to test DPK, without cloning the repo. You can run it either on Google Colab or you can use your local environment (by downloading just the notebook). We use a temporary folder for input and output, but users are encouraged to use their own input folder.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# %%capture
# !pip install "data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2"
# !pip install pandas
import urllib.request
import shutil

# %%
shutil.os.makedirs("tmp/input", exist_ok=True)
urllib.request.urlretrieve("https://raw.githubusercontent.com/data-prep-kit/data-prep-kit/dev/transforms/language/docling2parquet/test-data/input/archive1.zip", "tmp/input/archive1.zip")
urllib.request.urlretrieve("https://raw.githubusercontent.com/data-prep-kit/data-prep-kit/dev/transforms/language/docling2parquet/test-data/input/redp5110-ch1.pdf", "tmp/input/redp5110-ch1.pdf")
# Out:
# ('tmp/input/redp5110-ch1.pdf', <http.client.HTTPMessage at 0x7d7aa5391310>)

# %%
# !pip install --upgrade numpy
# !pip install --upgrade pandas
# Out:
# Requirement already satisfied: numpy in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (1.26.4)
# Collecting numpy
#   Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.8 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 74.4 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas 2.1.4 requires numpy<2,>=1.23.2; python_version == "3.11", but you have numpy 2.2.6 which is incompatible.
# tensorflow 2.14.1 requires numpy<2.0.0,>=1.23.5, but you have numpy 2.2.6 which is incompatible.
# matplotlib 3.8.0 requires numpy<2,>=1.21, but you have numpy 2.2.6 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.2.6 which is incompatible.
# numba 0.59.1 requires numpy<1.27,>=1.22, but you have numpy 2.2.6 which is incompatible.
# tf-model-optimization-nightly 0.7.4.dev0 requires numpy~=1.23, but you have numpy 2.2.6 which is incompatible.
# deepsearch-glm 0.26.1 requires numpy<2.0.0,>=1.26.4; python_version >= "3.9" and python_version < "3.13", but you have numpy 2.2.6 which is incompatible.
# data-prep-toolkit 0.2.5 requires numpy<1.29.0, but you have numpy 2.2.6 which is incompatible.
# docling-ibm-models 2.0.3 requires numpy<2.0.0,>=1.24.4; python_version < "3.13", but you have numpy 2.2.6 which is incompatible.
# autoai-ts-libs 4.0.15 requires numpy==1.26.*, but you have numpy 2.2.6 which is incompatible.
# autoai-ts-libs 4.0.15 requires scipy==1.11.*, but you have scipy 1.15.3 which is incompatible.
# autoai-libs 2.0.16 requires numpy==1.26.*, but you have numpy 2.2.6 which is incompatible.
# langchain-community 0.3.3 requires numpy<2,>=1; python_version < "3.12", but you have numpy 2.2.6 which is incompatible.
# langchain-chroma 0.1.4 requires numpy<2,>=1; python_version < "3.12", but you have numpy 2.2.6 which is incompatible.
# langchain 0.3.4 requires numpy<2,>=1; python_version < "3.12", but you have numpy 2.2.6 which is incompatible.
# Successfully installed numpy-2.2.6
# Requirement already satisfied: pandas in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (2.1.4)
# Collecting pandas
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 93.1 MB/s eta 0:00:00:00:010:01
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# deepsearch-glm 0.26.1 requires numpy<2.0.0,>=1.26.4; python_version >= "3.9" and python_version < "3.13", but you have numpy 2.2.6 which is incompatible.
# autoai-ts-libs 4.0.15 requires numpy==1.26.*, but you have numpy 2.2.6 which is incompatible.
# autoai-ts-libs 4.0.15 requires pandas==2.1.*, but you have pandas 2.2.3 which is incompatible.
# autoai-ts-libs 4.0.15 requires scipy==1.11.*, but you have scipy 1.15.3 which is incompatible.
# autoai-libs 2.0.16 requires numpy==1.26.*, but you have numpy 2.2.6 which is incompatible.
# autoai-libs 2.0.16 requires pandas==2.1.*, but you have pandas 2.2.3 which is incompatible.
# ibm-watson-machine-learning 1.0.367 requires pandas<2.2.0,>=0.24.2, but you have pandas 2.2.3 which is incompatible.
# ibm-watson-openscale 3.0.46 requires pandas<=2.1.9,>=1.4.3, but you have pandas 2.2.3 which is incompatible.
# Successfully installed pandas-2.2.3

# %%
# !pip install virtualenv
# !virtualenv venv
# !source venv/bin/activate
# !pip install "data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2" pandas
#Continue with your notebook from here, but ensure you run all installations within the created virtual environment.
# Out:
# Collecting virtualenv
#   Downloading virtualenv-20.31.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv)
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: filelock<4,>=3.12.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from virtualenv) (3.13.1)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from virtualenv) (3.10.0)
# Downloading virtualenv-20.31.2-py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 52.0 MB/s eta 0:00:0000:0100:01
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 45.4 MB/s eta 0:00:00
# Installing collected packages: distlib, virtualenv
# Successfully installed distlib-0.3.9 virtualenv-20.31.2
# created virtual environment CPython3.11.9.final.0-64 in 469ms
#   creator CPython3Posix(dest=/home/wsuser/work/venv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, via=copy, app_data_dir=/home/wsuser/.local/share/virtualenv)
#     added seed packages: pip==25.1.1, setuptools==80.3.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
# Requirement already satisfied: data-prep-toolkit-transforms==1.0.0a2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.0.0a2)
# Requirement already satisfied: pandas in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: data-prep-toolkit>=0.2.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from data-prep-toolkit-transforms==1.0.0a2->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.2.5)
# Requirement already satisfied: docling-core==2.3.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.3.0)
# Requirement already satisfied: docling-ibm-models==2.0.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.0.3)
# Requirement already satisfied: deepsearch-glm==0.26.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.26.1)
# Requirement already satisfied: docling==2.3.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.3.1)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.2.0)
# Requirement already satisfied: docutils!=0.21 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from deepsearch-glm==0.26.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.21.2)
# Collecting numpy<2.0.0,>=1.26.4 (from deepsearch-glm==0.26.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from deepsearch-glm==0.26.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from deepsearch-glm==0.26.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.32.3)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from deepsearch-glm==0.26.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (13.7.1)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from deepsearch-glm==0.26.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from deepsearch-glm==0.26.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (4.66.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (4.12.3)
# Requirement already satisfied: certifi>=2024.7.4 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2025.4.26)
# Requirement already satisfied: docling-parse<3.0.0,>=2.0.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.1.2)
# Requirement already satisfied: easyocr<2.0,>=1.7 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.7.2)
# Requirement already satisfied: huggingface_hub<1,>=0.23 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.29.2)
# Requirement already satisfied: marko<3.0.0,>=2.1.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.1.3)
# Requirement already satisfied: pyarrow<17.0.0,>=16.1.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (16.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.10.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.6.0)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.30.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (4.30.1)
# Requirement already satisfied: python-docx<2.0.0,>=1.1.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.1.2)
# Requirement already satisfied: python-pptx<2.0.0,>=1.0.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.0.2)
# Requirement already satisfied: rtree<2.0.0,>=1.3.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.4.0)
# Requirement already satisfied: scipy<2.0.0,>=1.14.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.15.3)
# Requirement already satisfied: typer<0.13.0,>=0.12.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.12.5)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling-core==2.3.0->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.1.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling-core==2.3.0->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (4.19.2)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling-core==2.3.0->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (10.3.0)
# Requirement already satisfied: jsonlines<4.0.0,>=3.1.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (3.1.0)
# Requirement already satisfied: lxml<5.0.0,>=4.9.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (4.9.3)
# Requirement already satisfied: mean_average_precision<2022.0.0.0,>=2021.4.26.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2021.4.26.0)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.6.0.66 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (4.11.0.86)
# Requirement already satisfied: torch<3.0.0,>=2.2.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.7.0)
# Requirement already satisfied: torchvision<1,>=0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.16.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: boto3<1.35.94,>=1.35.74 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from data-prep-toolkit>=0.2.3->data-prep-toolkit-transforms==1.0.0a2->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.35.93)
# Requirement already satisfied: mmh3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from data-prep-toolkit>=0.2.3->data-prep-toolkit-transforms==1.0.0a2->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (5.1.0)
# Requirement already satisfied: psutil in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from data-prep-toolkit>=0.2.3->data-prep-toolkit-transforms==1.0.0a2->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (5.9.0)
# Requirement already satisfied: polars>=1.9.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from data-prep-toolkit>=0.2.3->data-prep-toolkit-transforms==1.0.0a2->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.30.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.5)
# Requirement already satisfied: botocore<1.36.0,>=1.35.93 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from boto3<1.35.94,>=1.35.74->data-prep-toolkit>=0.2.3->data-prep-toolkit-transforms==1.0.0a2->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.35.99)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from boto3<1.35.94,>=1.35.74->data-prep-toolkit>=0.2.3->data-prep-toolkit-transforms==1.0.0a2->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from boto3<1.35.94,>=1.35.74->data-prep-toolkit>=0.2.3->data-prep-toolkit-transforms==1.0.0a2->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.10.4)
# Requirement already satisfied: scikit-image in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.22.0)
# Requirement already satisfied: python-bidi in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.6.6)
# Requirement already satisfied: PyYAML in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (6.0.1)
# Requirement already satisfied: Shapely in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.1.1)
# Requirement already satisfied: pyclipper in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.3.0.post6)
# Requirement already satisfied: ninja in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.11.1.4)
# Requirement already satisfied: filelock in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from huggingface_hub<1,>=0.23->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from huggingface_hub<1,>=0.23->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from huggingface_hub<1,>=0.23->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (23.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from huggingface_hub<1,>=0.23->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (4.12.2)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from jsonlines<4.0.0,>=3.1.0->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core==2.3.0->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core==2.3.0->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core==2.3.0->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.10.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.27.1)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from python-pptx<2.0.0,>=1.0.2->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->deepsearch-glm==0.26.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->deepsearch-glm==0.26.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->deepsearch-glm==0.26.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.26.19)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from rich<14.0.0,>=13.7.0->deepsearch-glm==0.26.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from rich<14.0.0,>=13.7.0->deepsearch-glm==0.26.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.15.1)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (3.3.0)
# Requirement already satisfied: setuptools>=40.8.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from triton==3.3.0->torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (72.1.0)
# Requirement already satisfied: click>=8.0.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from typer<0.13.0,>=0.12.5->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from typer<0.13.0,>=0.12.5->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->deepsearch-glm==0.26.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from sympy>=1.13.3->torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from jinja2->torch<3.0.0,>=2.2.2->docling-ibm-models==2.0.3->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.1.3)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (2023.4.12)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[pdf2parquet]==1.0.0a2) (0.3)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 73.6 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autoai-ts-libs 4.0.15 requires pandas==2.1.*, but you have pandas 2.2.3 which is incompatible.
# autoai-ts-libs 4.0.15 requires scipy==1.11.*, but you have scipy 1.15.3 which is incompatible.
# autoai-libs 2.0.16 requires pandas==2.1.*, but you have pandas 2.2.3 which is incompatible.
# ibm-watson-machine-learning 1.0.367 requires pandas<2.2.0,>=0.24.2, but you have pandas 2.2.3 which is incompatible.
# ibm-watson-openscale 3.0.46 requires pandas<=2.1.9,>=1.4.3, but you have pandas 2.2.3 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
from dpk_pdf2parquet.transform_python import Pdf2Parquet
from dpk_pdf2parquet.transform import pdf2parquet_contents_types

# %%
Pdf2Parquet(input_folder= "tmp/input",
               output_folder= "tmp/output",
               data_files_to_use=['.pdf', '.zip'],
               pdf2parquet_contents_type=pdf2parquet_contents_types.JSON).transform()
# Out:
# 02:46:56 INFO - pdf2parquet parameters are : {'batch_size': -1, 'artifacts_path': None, 'contents_type': <pdf2parquet_contents_types.JSON: 'application/json'>, 'do_table_structure': True, 'do_ocr': True, 'ocr_engine': <pdf2parquet_ocr_engine.EASYOCR: 'easyocr'>, 'bitmap_area_threshold': 0.05, 'pdf_backend': <pdf2parquet_pdf_backend.DLPARSE_V2: 'dlparse_v2'>, 'double_precision': 8}
# 02:46:56 INFO - pipeline id pipeline_id
# 02:46:56 INFO - code location None
# 02:46:56 INFO - data factory data_ is using local data access: input_folder - tmp/input output_folder - tmp/output
# 02:46:56 INFO - data factory data_ max_files -1, n_sample -1
# 02:46:56 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.pdf', '.zip'], files to checkpoint ['.parquet']
# 02:46:56 INFO - orchestrator pdf2parquet started at 2025-05-22 02:46:56
# 02:46:56 INFO - Number of files is 2, source profile {'max_file_size': 0.3013172149658203, 'min_file_size': 0.2757863998413086, 'total_file_size': 0.5771036148071289}
# 02:46:56 INFO - Initializing models
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# otslp_all_standard_094_clean.check:   0%|          | 0.00/213M [00:00<?, ?B/s]
# tm_config.json:   0%|          | 0.00/7.09k [00:00<?, ?B/s]
# .gitignore:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.49k [00:00<?, ?B/s]
# otslp_all_fast.check:   0%|          | 0.00/146M [00:00<?, ?B/s]
# model.pt:   0%|          | 0.00/202M [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.71k [00:00<?, ?B/s]
# tm_config.json:   0%|          | 0.00/7.09k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/41.0 [00:00<?, ?B/s]
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# 02:47:10 INFO - Processing archive_doc_filename='2305.03393v1-pg9.pdf'
# 02:47:13 INFO - Processing archive_doc_filename='2408.09869v1-pg1.pdf'
# 02:47:14 INFO - Completed 1 files (50.0%) in 0.067 min
# 02:47:27 INFO - Completed 2 files (100.0%) in 0.274 min
# 02:47:27 INFO - Done processing 2 files, waiting for flush() completion.
# 02:47:27 INFO - done flushing in 0.0 sec
# 02:47:27 INFO - Completed execution in 0.513 min, execution result 0
# 0

# %%
import pyarrow.parquet as pq
import pandas as pd
table = pq.read_table('tmp/output/archive1.parquet')
table.to_pandas()
# Out:
#                filename                                           contents  \
# 0  2305.03393v1-pg9.pdf  {"schema_name":"DoclingDocument","version":"1....
# 1  2408.09869v1-pg1.pdf  {"schema_name":"DoclingDocument","version":"1....
#
#    num_pages  num_tables  num_doc_elements  \
# 0          1           1                 9
# 1          1           0                12
#
#                             document_id        document_hash  ext  \
# 0  5e7d1430-59b1-405d-a39f-9fb16ba28c25  3463920545297462180  pdf
# 1  33d355f8-c500-4f60-9ab4-4d1cdd7c0c5e   582377908831471240  pdf
#
#                                                 hash   size  \
# 0  467dcf637d2efd3f7ad3ed4aafe51618d2d4a950c80270...  39760
# 1  8ed0cb6d8767bacf9ce8becc77f954cae557d21d35ec29...   8306
#
#                 date_acquired  pdf_convert_time source_filename
# 0  2025-05-22T02:47:13.418666          2.748252    archive1.zip
# 1  2025-05-22T02:47:14.687021          1.264096    archive1.zip

# %%
table = pq.read_table('tmp/output/redp5110-ch1.parquet')
table.to_pandas()
# Out:
#            filename                                           contents  \
# 0  redp5110-ch1.pdf  {"schema_name":"DoclingDocument","version":"1....
#
#    num_pages  num_tables  num_doc_elements  \
# 0          5           0                48
#
#                             document_id      document_hash  ext  \
# 0  63876f61-3aa4-41a6-893d-3905bea86222  74198560999363607  pdf
#
#                                                 hash   size  \
# 0  572c2937fa0e2659f43d74d157650bc39fe93ac0a5df4f...  35185
#
#                 date_acquired  pdf_convert_time   source_filename
# 0  2025-05-22T02:47:27.081101         12.385113  redp5110-ch1.pdf

# %%
import os

# Print current working directory
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /home/wsuser/work

# %%
# List folders in the current directory
print(os.listdir('.'))

# Check if 'tmp' is in the current directory
if 'tmp' in os.listdir('.'):
    print("Contents of tmp:")
    print(os.listdir('tmp'))
    if 'output' in os.listdir('tmp'):
        print("Contents of tmp/output:")
        print(os.listdir('tmp/output'))
# Out:
# ['tmp', 'venv']
# Contents of tmp:
# ['input', 'output']
# Contents of tmp/output:
# ['redp5110-ch1.parquet', 'metadata.json', 'archive1.parquet']

# %%
# Search for the parquet file recursively
for root, dirs, files in os.walk('.'):
    for file in files:
        if file.endswith('archive1.parquet'):
            print("Found:", os.path.join(root, file))
# Out:
# Found: ./tmp/output/archive1.parquet

# %%
#Use Shell Commands to Search(optional)
# !find . -name "archive1.parquet"
# Out:
# ./tmp/output/archive1.parquet
